# %% [markdown]
# # Jansson Farrar Random Field
#
# **-Reference:**
#
# **-Orignal Implementation:**
#
# **-Default parameters constrained using (see reference publication):**

# %%
import ImagineModels as img
from plotting_helpers import plot_slice

# %% [markdown]
# #### 1. Visualizing the model

# %%
model = img.JF12RandomField()
shape = [100, 100, 20] # necessarily a list of 3 ints! 
increment = [.20, .20, .20]  
refpoint = [-10., -10., -2.]
vmin = -0.6
vmax = 0.6

seed = 12

model_on_grid = model.on_grid(shape=shape, reference_point=refpoint, increment=increment, seed=seed)
plot_slice(model_on_grid, 0, 2, shape, refpoint, increment, vmin, vmax)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/sebastian/Development/CppProjects/imagine-models/demos/python/model_examples/jf12_random_demo.ipynb Cell 5 line 8
#       <a href='vscode-notebook-cell:/home/sebastian/Development/CppProjects/imagine-models/demos/python/model_examples/jf12_random_demo.ipynb#W3sZmlsZQ%3D%3D?line=4'>5</a> vmin = -0.6
#       <a href='vscode-notebook-cell:/home/sebastian/Development/CppProjects/imagine-models/demos/python/model_examples/jf12_random_demo.ipynb#W3sZmlsZQ%3D%3D?line=5'>6</a> vmax = 0.6
# ----> <a href='vscode-notebook-cell:/home/sebastian/Development/CppProjects/imagine-models/demos/python/model_examples/jf12_random_demo.ipynb#W3sZmlsZQ%3D%3D?line=7'>8</a> model_on_grid = model.on_grid(shape=shape, reference_point=refpoint, increment=increment)
#       <a href='vscode-notebook-cell:/home/sebastian/Development/CppProjects/imagine-models/demos/python/model_examples/jf12_random_demo.ipynb#W3sZmlsZQ%3D%3D?line=8'>9</a> plot_slice(model_on_grid, 0, 2, shape, refpoint, increment, vmin, vmax)
#
# TypeError: on_grid(): incompatible function arguments. The following argument types are supported:
#     1. (self: _ImagineModels.RandomVectorField, *, shape: List[int[3]], reference_point: List[float[3]], increment: List[float[3]], seed: int) -> list
#     2. (self: _ImagineModels.RandomVectorField, seed: int) -> list
#
# Invoked with: <_ImagineModels.JF12RandomField object at 0x7f4edb5340b0>; kwargs: shape=[100, 100, 20], reference_point=[-10.0, -10.0, -2.0], increment=[0.2, 0.2, 0.2]

# %%
plot_slice(model_on_grid, 1, 2, shape, refpoint, increment, vmin, vmax)

# %%
plot_slice(model_on_grid, 2, 2, shape, refpoint, increment, vmin, vmax)

# %%
plot_slice(model_on_grid, 0, 1, shape, refpoint, increment, vmin, vmax)

# %%
plot_slice(model_on_grid, 1, 1, shape, refpoint, increment, vmin, vmax)

# %%
plot_slice(model_on_grid, 2, 1, shape, refpoint, increment, vmin, vmax)

# %% [markdown]
# ### 2. The parameters
#
# **TBD**
