# %% [markdown]
# # Shaw et al model for the Galactic halo bubble
#
# **-Reference:** [SVT22 model](https://academic.oup.com/mnras/article/517/2/2534/6731784)

# %%
import ImagineModels as img
import numpy as np
from plotting_helpers import plot_slice

# %% [markdown]
# #### 1. Visualizing the model

# %%
model = img.SVT22()
shape = [200, 200, 200] # necessarily a list of 3 ints! 
increment = [.20, .20, .20]  
refpoint = [-20., -20., -20.]
# refpoint = [1., 1., 1.]

vmin = -3.96
vmax = 4.96

model_on_grid = model.on_grid(shape=shape, reference_point=refpoint, increment=increment)
# plot_slice(model_on_grid, 2, shape, refpoint, increment, vmin, vmax, vec_dim=0, field_name='JF12 regular')

# %%
plot_slice((model_on_grid), 1, shape, refpoint, increment, vmin, vmax, quiver=True, field_name='SVT22 regular', amplitude=True,cmap='jet')
# strong z-component (X-field) visible
